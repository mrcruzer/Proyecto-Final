# %% [markdown]
# EL objetivo del siguiente notebook es realizar una primera visualización de los datasets de Google y Yelp para poder plantear los objetivos del trabajo.

# %%
#Importamos las librerías necesarias
import pandas as pd

# %%
url = "https://drive.google.com/file/d/186FyE42tlY7HOozKxtsvAcFBbZi1OVHh/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

google_metadata = pd.read_csv(url)

google_metadata.info()

# %%
google_metadata.drop_duplicates(subset='gmap_id',inplace=True) #Descartamos los duplicados de gmap_id que es el identificador de lugar

google_metadata.dropna(subset='category',inplace=True)      #Descartamos los nulos debajo de 'category'
google_metadata.reset_index(inplace=True,drop=True)         #Reseteamos indice

#Hallamos los índices de los restaurants
restaurant_indexes = []
for i in range(google_metadata.shape[0]):
    for j in range(len(google_metadata['category'][i])):
        if google_metadata['category'][i][j].find('estaura')!=-1:
            restaurant_indexes.append(i)
            break

google = google_metadata[google_metadata.index.isin(restaurant_indexes)]    #Filtramos restaurants
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 google_metadata.drop_duplicates(subset='gmap_id',inplace=True) #Descartamos los duplicados de gmap_id que es el identificador de lugar
# ----> 3 google_metadata.dropna(subset='category',inplace=True)      #Descartamos los nulos debajo de 'category'
#       4 google_metadata.reset_index(inplace=True,drop=True)         #Reseteamos indice
#       6 #Hallamos los índices de los restaurants
#
# File c:\Users\isaac avelino\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
datos = pd.read_json("../Data/probando/1.json", lines=True)
datos.head(5)

# %%
datos.to_pickle("../Data/probando/1.pkl")

# %%
datos1 = pd.read_pickle("../Data/probando/1.pkl")
datos1.head(5)
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# ...

# %%
#Importamos la metadata del dataset de google
google_metadata = pd.read_json('google_metadata_1.json',lines=True)
google_metadata.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# ...

# %%
google_metadata.dropna(subset='category',inplace=True)
google_metadata.reset_index(inplace=True)

# %%
restaurant_indexes = []
for i in range(google_metadata.shape[0]):
    try:
        for j in range(len(google_metadata['category'][i])):
            if google_metadata['category'][i][j].find('estaura')!=-1:
                restaurant_indexes.append(i)
                break
    except:
        print(i)
len(restaurant_indexes)
# Out:
# 10978

# %%
restaurants = google_metadata[google_metadata.index.isin(restaurant_indexes)]
restaurants.head()
# Out:
#     index                                   name  \
# 2       2                           San Soo Dang
# 6       6                           Vons Chicken
# 8       8  Sweet Rewards Gluten Free Bakery, LLC
# 67     68                        Vivi Bubble Tea
# 94     96                              Hale Pops
#
#                                               address  \
# 2   San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 6   Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 8   Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...
# 67  Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...
# 94   Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
#
#                                   gmap_id  \
# 2   0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 6   0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 8    0x87ec235c54d25b31:0x3b75fb5facc602f
# 67  0x89c6c89efcaed69d:0xded973f6033e7dba
# 94   0x7c00456eecad3111:0x8217f9600c51f33
#
# ...

# %%
#Observamos un poco
google_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272740 entries, 0 to 272739
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             272740 non-null  int64
#  1   name              272733 non-null  object
#  2   address           262678 non-null  object
#  3   gmap_id           272740 non-null  object
#  4   description       13102 non-null   object
#  5   latitude          272740 non-null  float64
#  6   longitude         272740 non-null  float64
#  7   category          272740 non-null  object
#  8   avg_rating        272740 non-null  float64
#  9   num_of_reviews    272740 non-null  int64
#  10  price             13356 non-null   object
#  11  hours             192057 non-null  object
#  12  MISC              194972 non-null  object
#  13  state             195105 non-null  object
#  14  relative_results  237539 non-null  object
#  15  url               272740 non-null  object
# ...

# %%
#Observamos el registro final para ver que coincida con el último del json
google_metadata.tail()
# Out:
#                                    name  \
# 274996                     Maven Realty
# 274997               Stone Castle Fence
# 274998  Health Insurance Solutions Team
# 274999          Bernard Building Center
# 275000    HMR Motor Works and Auto Care
#
#                                                   address  \
# 274996  Maven Realty, 2180 McMillan Ave #71672, North ...
# 274997  Stone Castle Fence, 124 Cypress Gardens Rd, Mo...
# 274998  Health Insurance Solutions Team, 6650 Rivers A...
# 274999  Bernard Building Center, 27300 M-32, M-32, Hil...
# 275000       HMR Motor Works and Auto Care, Mio, MI 48647
#
#                                       gmap_id description   latitude  \
# 274996  0x88fe64e7daceaaab:0x101c046dcadcc9c3        None  32.857737
# 274997  0x88fe59f4602c95fd:0x57e2b1904d9e6949        None  33.089951
# 274998  0x88fe71f9617c15e1:0x89518c1d251706bf        None  32.918858
# 274999  0x4d34c7517d6e6e29:0x7fe553ee2f090cf0        None  45.056691
# ...

# %%
#Importamos reviews del estado de alabama del dataset de google.
alabama_reviews = pd.read_json('google_alabama_reviews_1.json',lines=True)
alabama_reviews.head()
# Out:
# c:\Users\larra\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
#         user_id                    name           time  rating  \
# 0  1.140438e+20           Kanisha Mixon  1597168272670       5
# 1  1.160090e+20          Brandie Hodges  1609899039594       5
# 2  1.062399e+20             Sharon King  1547235290843       4
# 3  1.049701e+20         Veronica Pierce  1517709403534       5
# 4  1.105875e+20  Whitney Waldon Collier  1535245718492       5
#
#                                                 text  pics  resp  \
# 0  Very Personable staff! Beautiful and clean env...  None  None
# 1                               Best clothing intown  None  None
# 2                                               None  None  None
# 3                                               None  None  None
# ...

# %%
alabama_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  150000 non-null  float64
#  1   name     150000 non-null  object
#  2   time     150000 non-null  int64
#  3   rating   150000 non-null  int64
#  4   text     82943 non-null   object
#  5   pics     3087 non-null    object
#  6   resp     20893 non-null   object
#  7   gmap_id  150000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 9.2+ MB

# %%
alabama_reviews.tail()
# Out:
#              user_id            name           time  rating  \
# 149995  1.165082e+20         Lee Lee  1601666489107       5
# 149996  1.080208e+20  Hayward Salter  1621994613217       5
# 149997  1.054646e+20   James McBride  1601863228986       4
# 149998  1.118869e+20  Karen Sullivan  1593013285677       1
# 149999  1.109920e+20      Scott Reid  1573317350293       4
#
#                                                      text  pics  resp  \
# 149995           Just a good old hardware friendly people  None  None
# 149996                                        Good people  None  None
# 149997  Good for locals needing supplies to fix damage...  None  None
# 149998  Very rude female employees at the cash counter...  None  None
# 149999  Good hardware and lumber store. Prices on lumb...  None  None
#
#                                       gmap_id
# 149995  0x889a89fd92d55353:0x78e335f5e98e75b2
# 149996  0x889a89fd92d55353:0x78e335f5e98e75b2
# ...

# %%
#Vemos que resultados entrega la primer review en la metadata
google_metadata[google_metadata['gmap_id']=='0x8862134e67ff5c87:0x38b5e2ae99cd1fcf']
# Out:
#                 name                                            address  \
# 460    Purple Peanut  Purple Peanut, 2357 Whitesburg Dr # D, Huntsvi...
# 27033  Purple Peanut  Purple Peanut, 2357 Whitesburg Dr # D, Huntsvi...
#
#                                      gmap_id description   latitude  \
# 460    0x8862134e67ff5c87:0x38b5e2ae99cd1fcf        None  34.713163
# 27033  0x8862134e67ff5c87:0x38b5e2ae99cd1fcf        None  34.713163
#
#        longitude    category  avg_rating  num_of_reviews price  \
# 460   -86.574041  [Boutique]         4.6              17  None
# 27033 -86.574041  [Boutique]         4.6              17  None
#
#                                                    hours  \
# 460    [[Thursday, Closed], [Friday, 10AM–5PM], [Satu...
# 27033  [[Thursday, Closed], [Friday, 10AM–5PM], [Satu...
#
#                                                     MISC  \
# 460    {'Service options': ['In-store shopping', 'Del...
# ...

# %%
#Observamos 2 cosas. Una es que aparentemente hay valores duplicados. La otra es que el gmap_id identifica al negocio.
#Observamos mas detenidamente la lista dentro de relative_results.
google_metadata['relative_results'].iloc[460]
# Out:
# ['0x886269389730ce8b:0xedffba4037968914',
#  '0x88626cba32c55791:0xb2b825009c312370',
#  '0x88626b52b85fa957:0x418f198557020e80',
#  '0x88626622a77eec85:0x71b49ce40b0a37f5',
#  '0x886269389730ce8b:0x1a711b728215c00a']

# %%
#Buscamos estos valores dentro del dataset (la fraccion que tenemos bajado)
google_metadata[google_metadata['gmap_id'].isin(google_metadata['relative_results'].iloc[460])]
# Out:
# Empty DataFrame
# Columns: [name, address, gmap_id, description, latitude, longitude, category, avg_rating, num_of_reviews, price, hours, MISC, state, relative_results, url]
# Index: []

# %%
#Buscamos un indice cuyos valores de relative_results se hayen en la fracción de dataset que tenemos.
for i in range(500):
    if not(google_metadata['relative_results'].iloc[i] is None):
        if google_metadata[google_metadata['gmap_id'].isin(google_metadata['relative_results'].iloc[i])]['name'].values.size > 0:
            print(i)
            break
# Out:
# 15

# %%
#Vemos de que negocio se trata
google_metadata.iloc[15:16]
# Out:
#                name                                            address  \
# 15  Angel-A Massage  Angel-A Massage, 5329 Dewey Dr, Fair Oaks, CA ...
#
#                                   gmap_id description  latitude   longitude  \
# 15  0x809adef58ae560bd:0x83412889e022ff70        None  38.66263 -121.308639
#
#                                              category  avg_rating  \
# 15  [Massage spa, Chiropractor, Massage, Massage t...         4.3
#
#     num_of_reviews price                                              hours  \
# 15               6  None  [[Thursday, 9:30AM–9:30PM], [Friday, 9:30AM–9:...
#
#     MISC                 state  \
# 15  None  Open ⋅ Closes 9:30PM
#
#                                      relative_results  \
# 15  [0x809adee9ac6f1bd7:0xe2e56d16919b9b8d, 0x809a...
#
#                                                   url
# 15  https://www.google.com/maps/place//data=!4m2!3...

# %%
#Observamos la lista de relative results
google_metadata['relative_results'].iloc[15]
# Out:
# ['0x809adee9ac6f1bd7:0xe2e56d16919b9b8d',
#  '0x809ade27605defc1:0xdedc5626a281fd93',
#  '0x809ade94e408288b:0xffef63e3b6d71ced',
#  '0x809ade549eb5f62b:0x88ea57ed966f9c6',
#  '0x809ade7192ece6ef:0xee80bbb2aba77a09']

# %%
#Observamos a que negocios llama
google_metadata[google_metadata['gmap_id'].isin(google_metadata['relative_results'].iloc[15])]
# Out:
#                  name                                            address  \
# 23     Orient Massage  Orient Massage, 5800 Madison Ave # U2, Sacrame...
# 26596  Orient Massage  Orient Massage, 5800 Madison Ave # U2, Sacrame...
#
#                                      gmap_id description   latitude  \
# 23     0x809adee9ac6f1bd7:0xe2e56d16919b9b8d        None  38.659634
# 26596  0x809adee9ac6f1bd7:0xe2e56d16919b9b8d        None  38.659634
#
#         longitude             category  avg_rating  num_of_reviews price  \
# 23    -121.327812  [Massage therapist]         3.6              15  None
# 26596 -121.327812  [Massage therapist]         3.6              15  None
#
#                                                    hours  MISC  \
# 23     [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...  None
# 26596  [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...  None
#
#                    state                                   relative_results  \
# ...

# %% [markdown]
# Evidentemente se trata de negocios que brindan servicios parecidos.
#
# En conclusión podemos observar que, en los dataset de googles, tenemos,por un lado, una serie de negocios (name, gmap_id), con su ubicación (address, latitude, longitude, url), categoria, algunas características (MISC) y referencia a negocios parecidos (relative results), además de datos sobre el horario. Y por otro lado, tenemos una serie de usuarios (user_id) que le otorgan puntaje (rating) a los negocios(gmap_id), en un momento determinado (time) y dejan un comentario.
#
# Vamos a inspeccionar los datasets de yelp.

# %%
#Importamos la información de los negocios.
yelp_business = pd.read_pickle('yelp/business.pkl')
yelp_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# ...

# %%
yelp_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
#Vemos porque se repiten los campos. Filtramos los repetidos.
repetead = yelp_business.iloc[:,14:]
repetead.head()
# Out:
#   business_id name address city state postal_code latitude longitude stars  \
# 0         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
# 1         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
# 2         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
# 3         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
# 4         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
#
#   review_count is_open attributes categories hours
# 0          NaN     NaN        NaN        NaN   NaN
# 1          NaN     NaN        NaN        NaN   NaN
# 2          NaN     NaN        NaN        NaN   NaN
# 3          NaN     NaN        NaN        NaN   NaN
# 4          NaN     NaN        NaN        NaN   NaN

# %%
#Vemos donde no tienen valores nulos
repetead[~repetead['business_id'].isna()]
# Out:
#                  business_id       name                             address  \
# 590   6_Zf2QsRHCH1RhbzA9inyw  STarbucks               8602 Hillsborough Ave
# 613   Iipfa9Kaac9XH5Vo8GQwvg  STarbucks                     5956 153 Avenue
# 978   oY6osC4Ch3PvguA7D1hh_w  STarbucks                    1251 Route 130 S
# 1296  pxuMxh5oC7W-PDN9wwvozg  STarbucks                     219 N Center St
# 1543  lo2VbA7Lwzu3i23pQpmzlw  STarbucks  1125 S Black Horse Pike, Space 575
#
#                      city state postal_code   latitude   longitude stars  \
# 590                 Tampa    LA       33615   27.99637  -82.580954   3.0
# 613              Edmonton    PA     T5Y 2W1  53.616147 -113.432424   3.5
# 978           Cinnaminson    AZ       08077  40.000157  -74.987313   4.5
# 1296                 Reno    FL       89501  39.527772 -119.812518   3.0
# 1543  Gloucester Township    NJ       08012   39.78403   -75.05207   3.0
#
# ...

# %%
#Tomamos los indices
indexes = repetead[~repetead['business_id'].isna()].index.values
indexes
# Out:
# array([ 590,  613,  978, 1296, 1543], dtype=int64)

# %%
#Vemos si estaríamos perdiendo algo de información si descartamos los campos que se repiten
yelp_business[yelp_business.index.isin(indexes)].iloc[:,:14]
# Out:
#                  business_id       name                             address  \
# 590   6_Zf2QsRHCH1RhbzA9inyw  Starbucks               8602 Hillsborough Ave
# 613   Iipfa9Kaac9XH5Vo8GQwvg  Starbucks                     5956 153 Avenue
# 978   oY6osC4Ch3PvguA7D1hh_w  Starbucks                    1251 Route 130 S
# 1296  pxuMxh5oC7W-PDN9wwvozg  Starbucks                     219 N Center St
# 1543  lo2VbA7Lwzu3i23pQpmzlw  Starbucks  1125 S Black Horse Pike, Space 575
#
#                      city state postal_code   latitude   longitude stars  \
# 590                 Tampa    LA       33615   27.99637  -82.580954   3.0
# 613              Edmonton    PA     T5Y 2W1  53.616147 -113.432424   3.5
# 978           Cinnaminson    AZ       08077  40.000157  -74.987313   4.5
# 1296                 Reno    FL       89501  39.527772 -119.812518   3.0
# 1543  Gloucester Township    NJ       08012   39.78403   -75.05207   3.0
#
# ...

# %%
#Descartamos y revisamos ahora
yelp_business = yelp_business.iloc[:,:14]
yelp_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
# ...

# %%
#Importamos el dataset tips
yelps_tips = pd.read_json('yelp/yelp_tip.json',lines=True)
yelps_tips.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text                date  \
# 0                     Avengers time with the ladies. 2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2             It's open even when you think it isn't 2013-08-18 00:56:08
# 3                          Very decent fried chicken 2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch 2012-10-06 19:43:09
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
yelps_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908915 entries, 0 to 908914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   business_id       908915 non-null  object
#  2   text              908915 non-null  object
#  3   date              908915 non-null  datetime64[ns]
#  4   compliment_count  908915 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.7+ MB

# %%
yelps_tips.tail()
# Out:
#                        user_id             business_id  \
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                          text                date  \
# 908910  Disappointed in one of your managers. 2021-09-11 19:18:57
# 908911                Great food and service. 2021-10-30 11:54:36
# 908912                    Love their Cubans!! 2021-11-05 13:18:56
# 908913                Great pizza great price 2021-11-20 16:11:44
# 908914      Food is good value but a bit hot! 2021-12-07 22:30:00
#
#         compliment_count
# 908910                 0
# 908911                 0
# 908912                 0
# 908913                 0
# 908914                 0

# %%
#Revisamos checkin
yelp_checkin = pd.read_json('yelp/checkin.json',lines=True)
yelp_checkin.head()
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...

# %%
yelp_checkin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131930 entries, 0 to 131929
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  131930 non-null  object
#  1   date         131930 non-null  object
# dtypes: object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# Vamos a intentar averiguar que quiere decir las fechas debajo de date

# %%
yelp_business[yelp_business['business_id']==yelp_checkin['business_id'].values[0]]
# Out:
#                   business_id               name           address  \
# 29889  ---kPU91CF4Lq2-WlRu9Lw  Frankie's Raw Bar  4903 State Rd 54
#
#                   city state postal_code   latitude  longitude stars  \
# 29889  New Port Richey    FL       34652  28.217288 -82.733344   4.5
#
#       review_count is_open                                         attributes  \
# 29889           24       1  {'Alcohol': 'u'none'', 'OutdoorSeating': 'True...
#
#                                               categories  \
# 29889  Seafood, Restaurants, Latin American, Food, Fo...
#
#                                                    hours
# 29889  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...

# %%
#Vemos que hay debajo de date
yelp_checkin['date'].values[0]
# Out:
# '2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020-07-24 22:42:27, 2020-10-24 21:36:13, 2020-12-09 21:23:33, 2021-01-20 17:34:57, 2021-04-30 21:02:03, 2021-05-25 21:16:54, 2021-08-06 21:08:08, 2021-10-02 15:15:42, 2021-11-11 16:23:50'

# %%
#Armamos una lista y vemos el tamaño
len(yelp_checkin['date'].values[0].split(','))
# Out:
# 11

# %% [markdown]
# No son las fechas de las 24 reviews. No le encuentro sentido.
#
# Sin embargo, de observar el documento "Diccionario de datos", podemos decir que tenemos la misma informacion que en el dataset de Google. En Yelp tenemos más información acerca del usuario.
