# %%
#Importamos pandas
import pandas as pd

# %%
#Importamos el dataset de google
google = pd.read_pickle('restaurants_google_final.pkl')
google.head()
# Out:
#                            Id_Restaurant  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 2   0x87ec235c54d25b31:0x3b75fb5facc602f
# 3  0x89c6c89efcaed69d:0xded973f6033e7dba
# 4   0x7c00456eecad3111:0x8217f9600c51f33
#
#                                   Nombre        Ciudad Estado Cod_postal  \
# 0                           San Soo Dang   Los Angeles     CA      90005
# 1                           Vons Chicken     La Mirada     CA      90638
# 2  Sweet Rewards Gluten Free Bakery, LLC        Waukee     IA      50263
# 3                        Vivi Bubble Tea  Philadelphia     PA      19147
# 4                              Hale Pops          Laie     HI      96762
#
#      Latitud    Longitud                              Tipo  \
# 0  34.058092 -118.292130               [Korean restaurant]
# 1  33.916402 -118.010855                      [Restaurant]
# 2  41.616079  -93.865487  [Bakery, Health food restaurant]
# 3  39.940293  -75.150923                      [Restaurant]
# 4  21.637796 -157.920714                      [Restaurant]
#
#                                            Atributos
# 0  {'Service options': ['Takeout', 'Dine-in', 'De...
# 1  {'Service options': ['Outdoor seating', 'Curbs...
# 2                  {'Service options': ['Delivery']}
# 3  {'Service options': ['Delivery'], 'Amenities':...
# 4  {'Service options': ['Outdoor seating', 'Takeo...

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204702 entries, 0 to 204701
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Id_Restaurant  204702 non-null  object
#  1   Nombre         204702 non-null  object
#  2   Ciudad         204702 non-null  object
#  3   Estado         204702 non-null  object
#  4   Cod_postal     204702 non-null  object
#  5   Latitud        204702 non-null  float64
#  6   Longitud       204702 non-null  float64
#  7   Tipo           204702 non-null  object
#  8   Atributos      203478 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 14.1+ MB

# %%
#Importamos el dataset de yelp
yelp = pd.read_pickle('restaurants_yelp_final.pkl')
yelp.head()
# Out:
#             Id_Restaurant                 Nombre        Ciudad Estado  \
# 0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries  Philadelphia     CA
# 1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In  Ashland City     AZ
# 2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill        Affton     TN
# 3  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In     Nashville     MO
# 4  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck     Tampa Bay     MO
#
#   Cod_postal    Latitud   Longitud  \
# 0      19107  39.955505 -75.155564
# 1      37015  36.269593 -87.058943
# 2      63123  38.565165 -90.321087
# 3      37207  36.208102  -86.76817
# 4      33602  27.955269  -82.45632
#
#                                                 Tipo  \
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 2  Pubs, Restaurants, Italian, Bars, American (Tr...
# 3  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 4         Vietnamese, Food, Restaurants, Food Trucks
#
#                                            Atributos
# 0  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 2  {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 3  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 4  {'Alcohol': ''none'', 'OutdoorSeating': 'None'...

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50867 entries, 0 to 50866
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id_Restaurant  50867 non-null  object
#  1   Nombre         50867 non-null  object
#  2   Ciudad         50867 non-null  object
#  3   Estado         50867 non-null  object
#  4   Cod_postal     50867 non-null  object
#  5   Latitud        50867 non-null  object
#  6   Longitud       50867 non-null  object
#  7   Tipo           50867 non-null  object
#  8   Atributos      50310 non-null  object
# dtypes: object(9)
# memory usage: 3.5+ MB

# %%
#Reducimos los dataframes así es más liviano el trabajo
google_id_nombre_postal = google[['Id_Restaurant','Nombre','Cod_postal']]
yelp_id_nombre_postal = yelp[['Id_Restaurant','Nombre','Cod_postal']]

# %%
#Juntamos los dataframes
merge = pd.merge(google_id_nombre_postal,yelp_id_nombre_postal,on=['Nombre','Cod_postal'])
merge.head()
# Out:
#                          Id_Restaurant_x               Nombre Cod_postal  \
# 0  0x88c2fea614c52c8b:0x50e166caa05e8c0f  Kala' Bites & Brews      33708
# 1  0x89c6ac87db2a14b9:0x574dceb7c72ce463                 Wawa      18954
# 2  0x88c2c5c515fa6e53:0xee4f630ca314fe01      Flock and Stock      33602
# 3  0x89c1352001dc66d1:0xb8ca54f815dbb1bf              Dunkin'      08054
# 4  0x886466970c8a4e45:0xb01d015d268be1be           GoGo Sushi      37212
#
#           Id_Restaurant_y
# 0  IjulL_5PvUyJJyIHNQtu-w
# 1  g2bYK-Z3foqSnCiOPYtdsA
# 2  O1x70YS930qP3beQIystoA
# 3  H1bbYNKgk6JF9pKcBXyDXw
# 4  LIVL3r0LDrKl2RwbQ6TY8w

# %%
#Hay 4489 registros que coinciden en los dos datasets
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4489 entries, 0 to 4488
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id_Restaurant_x  4489 non-null   object
#  1   Nombre           4489 non-null   object
#  2   Cod_postal       4489 non-null   object
#  3   Id_Restaurant_y  4489 non-null   object
# dtypes: object(4)
# memory usage: 175.4+ KB

# %%
#Observamos los valores en el dataframe de google
google[google['Id_Restaurant'].isin(merge['Id_Restaurant_x'].values)].sort_values(by='Nombre').head()
# Out:
#                                 Id_Restaurant                 Nombre  \
# 748     0x89c6c77063630275:0x9462eb2e4d0f5f03   $5 Fresh Burger Stop
# 192075  0x89c6b1a739082ef7:0xf95519b3329603ef  &pizza - Willow Grove
# 9816    0x886b53aee6fa724f:0x5e094a4bf1083fae     10-01 Food & Drink
# 82908   0x886b50398d7986e5:0x45dce6bae9655660      10th Street Diner
# 185862  0x89c6c5ec2c62bc7b:0x3a2933907b662554            1100 Social
#
#               Ciudad Estado Cod_postal    Latitud   Longitud  \
# 748     Philadelphia     PA      19145  39.938200 -75.172553
# 192075  Willow Grove     PA      19090  40.140124 -75.123456
# 9816    Indianapolis     IN      46220  39.869571 -86.141461
# 82908   Indianapolis     IN      46201  39.781130 -86.109609
# 185862  Philadelphia     PA      19148  39.904156 -75.169127
#
#                                           Tipo  \
# 748                               [Restaurant]
# 192075                      [Pizza restaurant]
# 9816    [American restaurant, Bar, Restaurant]
# 82908                [Vegan restaurant, Diner]
# 185862                   [American restaurant]
#
#                                                 Atributos
# 748     {'Service options': ['Takeout'], 'Popular for'...
# 192075  {'Service options': ['No-contact delivery', 'D...
# 9816    {'Service options': ['Outdoor seating', 'Deliv...
# 82908   {'Service options': ['Curbside pickup', 'Takea...
# 185862  {'Service options': ['Takeout', 'Delivery'], '...

# %%
#Observamos los valores en el dataframe de yelp
yelp[yelp['Id_Restaurant'].isin(merge['Id_Restaurant_y'].values)].sort_values(by='Nombre').head()
# Out:
#                 Id_Restaurant                 Nombre        Ciudad Estado  \
# 38668  3zEedfqHtCrQEUsmPsDNsA   $5 Fresh Burger Stop  Philadelphia     PA
# 50691  zdv6HmtViGmQn4PVk9bAWQ  &pizza - Willow Grove  Willow Grove     PA
# 20041  lmXhXyGh_bLzY2eqgmCrJA     10-01 Food & Drink  Indianapolis     TN
# 2194   plYv1QpBDnLJ8cOtvZvmfA      10th Street Diner  Indianapolis     NJ
# 47749  x4855nj7vfdXeVpg5fREZA            1100 Social  Philadelphia     ID
#
#       Cod_postal    Latitud   Longitud  \
# 38668      19145   39.91852 -75.182777
# 50691      19090  40.140124 -75.123456
# 20041      46220  39.869548 -86.141411
# 2194       46201  39.781107 -86.109629
# 47749      19148  39.904169 -75.169129
#
#                                                     Tipo  \
# 38668                  Restaurants, Food Stands, Burmese
# 50691              Pizza, Vegetarian, Restaurants, Vegan
# 20041  Bars, Restaurants, Nightlife, Cocktail Bars, A...
# 2194                      Vegan, Vegetarian, Restaurants
# 47749       Bars, Nightlife, Restaurants, American (New)
#
#                                                Atributos
# 38668  {'RestaurantsTakeOut': 'None', 'RestaurantsDel...
# 50691  {'OutdoorSeating': 'True', 'GoodForKids': 'Tru...
# 20041  {'RestaurantsDelivery': 'False', 'BusinessPark...
# 2194   {'NoiseLevel': 'u'average'', 'RestaurantsGoodF...
# 47749  {'GoodForKids': 'False', 'Music': '{'dj': None...

# %% [markdown]
# Vamos a conservar los ids de google y descartar los de yelp. Entonces deberemos reemplazar los segundos con los primeros en las reviews.

# %%
#Descartamos los registros del dataset de yelp
indices_descarte = yelp[yelp['Id_Restaurant'].isin(merge['Id_Restaurant_y'].values)].index
yelp.drop(index=indices_descarte,inplace=True)
yelp.reset_index(inplace=True,drop=True)
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46378 entries, 0 to 46377
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id_Restaurant  46378 non-null  object
#  1   Nombre         46378 non-null  object
#  2   Ciudad         46378 non-null  object
#  3   Estado         46378 non-null  object
#  4   Cod_postal     46378 non-null  object
#  5   Latitud        46378 non-null  object
#  6   Longitud       46378 non-null  object
#  7   Tipo           46378 non-null  object
#  8   Atributos      45871 non-null  object
# dtypes: object(9)
# memory usage: 3.2+ MB

# %%
#Armamos un solo dataframe
restaurants = pd.concat([google,yelp],ignore_index=True)
restaurants.head()
# Out:
#                            Id_Restaurant  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 2   0x87ec235c54d25b31:0x3b75fb5facc602f
# 3  0x89c6c89efcaed69d:0xded973f6033e7dba
# 4   0x7c00456eecad3111:0x8217f9600c51f33
#
#                                   Nombre        Ciudad Estado Cod_postal  \
# 0                           San Soo Dang   Los Angeles     CA      90005
# 1                           Vons Chicken     La Mirada     CA      90638
# 2  Sweet Rewards Gluten Free Bakery, LLC        Waukee     IA      50263
# 3                        Vivi Bubble Tea  Philadelphia     PA      19147
# 4                              Hale Pops          Laie     HI      96762
#
#      Latitud    Longitud                              Tipo  \
# 0  34.058092  -118.29213               [Korean restaurant]
# 1  33.916402 -118.010855                      [Restaurant]
# 2  41.616079  -93.865487  [Bakery, Health food restaurant]
# 3  39.940293  -75.150923                      [Restaurant]
# 4  21.637796 -157.920714                      [Restaurant]
#
#                                            Atributos
# 0  {'Service options': ['Takeout', 'Dine-in', 'De...
# 1  {'Service options': ['Outdoor seating', 'Curbs...
# 2                  {'Service options': ['Delivery']}
# 3  {'Service options': ['Delivery'], 'Amenities':...
# 4  {'Service options': ['Outdoor seating', 'Takeo...

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251080 entries, 0 to 251079
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Id_Restaurant  251080 non-null  object
#  1   Nombre         251080 non-null  object
#  2   Ciudad         251080 non-null  object
#  3   Estado         251080 non-null  object
#  4   Cod_postal     251080 non-null  object
#  5   Latitud        251080 non-null  object
#  6   Longitud       251080 non-null  object
#  7   Tipo           251080 non-null  object
#  8   Atributos      249349 non-null  object
# dtypes: object(9)
# memory usage: 17.2+ MB

# %%
#Exportamos
restaurants.to_pickle('restaurants.pkl')

# %% [markdown]
# Ahora resta modificar las reviews para que todas las que eliminamos de yelp pasen a referirse a google.
